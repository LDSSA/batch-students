# %% [markdown]
# # BLU05 - Learning Notebook - Part 1 of 3 - Time Series Components

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

import utils

plt.rcParams['figure.figsize'] = (10,4.8)

# %% [markdown]
# In the previous BLU, you learned the fundamental concepts for modelling time series and in this BLU you'll finally learn how to actually model them. For that, we're going to dive a bit deeper into the time series components with a very useful library: [statsmodels](https://www.statsmodels.org/stable/index.html).
#
# As you may have realized, time series are sneaky things. Sometimes noise looks like signal and signal looks like noise.
#
# A frequent problem with time series is answering the open, yet crucial question: _"is there any kind of signal here?"_
#
# Various datasets are used in this BLU. Feel free to get a better understanding of the data by exploring the original data files (something which that scientists have to do 99.9% of the time). You might find some interesting stuff there :-)
#
# The first thing to do, as always, is to ~~run a highly complex LSTM analysis on the deep learning blockchain~~ **plot the data**. We start with the airline passenger dataset you already know.

# %%
airlines = utils.load_airlines_series()

# %%
airlines.plot();
plt.xlabel('Time')
plt.title('# Passengers per month (in thousands)');

# %% [markdown]
# ## 1. Seasonal Decomposition
#
# In the previous BLU, you were introduced to the different components of a time series:
# - Trend (T)
# - Cyclical (C)
# - Seasonal (S)
# - Irregular (I)
#
# Additionally, we saw two ways of combining these components:
# 1. additive ($Y = T + C + S + I$)
# 1. multiplicative ($Y = T \cdot C \cdot S \cdot I$)
#
# But...how do we know if our time series is additive or multiplicative? Citing [Hyndman & Athanasopoulos](https://otexts.org/fpp3/components.html)
#
# > _The additive decomposition is the most appropriate if the magnitude of the seasonal fluctuations, or the variation around the trend-cycle, does not vary with the level of the time series. When the variation in the seasonal pattern, or the variation around the trend-cycle, appears to be proportional to the level of the time series, then a multiplicative decomposition is more appropriate._
#
# (Level means the mean trend-cycle of the series.)

# %% [markdown]
# There are several ways to decompose a timeseries: using [moving averages](https://otexts.com/fpp2/moving-averages.html), [X11](https://otexts.org/fpp2/x11.html), [SEATS](https://otexts.org/fpp2/seats.html) and [STL](https://otexts.org/fpp2/stl.html). In this BLU, we will use the [seasonal_decompose](https://www.statsmodels.org/stable/generated/statsmodels.tsa.seasonal.seasonal_decompose.html#statsmodels.tsa.seasonal.seasonal_decompose) function from statsmodels, a python module with a rich set of models, plots and validation procedures for time series.
#
# We need to choose if we will use `model=additive` or `model=multiplicative`. In order to do that, we have to look at our time series and follow the Hyndman & Athanasopoulos guidelines that we read just before.
#
# Looking back at the previous plot, it seems that the trend is going up with time. To verify this visually, let's calculate a rolling mean over two years and plot the result.

# %%
airlines.rolling(24).mean().plot();
plt.xlabel('Year')
plt.title('Rolling mean: # Passengers per month (in thousands)');

# %% [markdown]
# It's clearly going up. Let's now check the variance around the trend by plotting the rolling standard deviation:

# %%
airlines.rolling(24).std().plot();
plt.xlabel('Time')
plt.title('Rolling standard deviation: # Passengers per month (in thousands)');

# %% [markdown]
# It's also going up. We can confirm by plotting the time series without the rolling mean:

# %%
(airlines-airlines.rolling(24).mean()).plot();
plt.xlabel('Time')
plt.title('Subtracted rolling mean: # Passengers per month (in thousands)');

# %% [markdown]
# We confirmed that the variance of this time series increases with the level (and that it has some seasonality as well). So, let's use the multiplicative model for decomposition:

# %%
decomposition = seasonal_decompose(airlines, model='multiplicative')
decomposition

# %% [markdown]
# This object allows us to visualize and access the following components:
# * Trend-Cycle (spoiler alert: it combines the trend and the cycle)
# * Seasonal
# * Residuals (an alternative name for the Irregular; the leftovers from the decomposition)
#
# `Statsmodels` includes a function to plot all 3 components at once.

# %%
fig = decomposition.plot()
fig.axes[0].set_title('# Passengers per month (in thousands)')
fig.axes[0].set_ylabel('Original')
fig.axes[3].lines[0].set_markersize(3)
fig.axes[3].set_xlabel('Time');

# %% [markdown]
# It also allows to directly access the values of the components.

# %%
decomposition.trend.head(10)
# Out:
# Month
# 1949-01-01           NaN
# 1949-02-01           NaN
# 1949-03-01           NaN
# 1949-04-01           NaN
# 1949-05-01           NaN
# 1949-06-01           NaN
# 1949-07-01    126.791667
# 1949-08-01    127.250000
# 1949-09-01    127.958333
# 1949-10-01    128.583333
# Name: trend, dtype: float64

# %%
decomposition.seasonal.head(10)
# Out:
# Month
# 1949-01-01    0.910230
# 1949-02-01    0.883625
# 1949-03-01    1.007366
# 1949-04-01    0.975906
# 1949-05-01    0.981378
# 1949-06-01    1.112776
# 1949-07-01    1.226556
# 1949-08-01    1.219911
# 1949-09-01    1.060492
# 1949-10-01    0.921757
# Name: seasonal, dtype: float64

# %%
decomposition.resid.head(10)
# Out:
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01    0.951664
# 1949-08-01    0.953401
# 1949-09-01    1.002220
# 1949-10-01    1.004028
# Name: resid, dtype: float64

# %% [markdown]
# ### 1.1 Let's see some more examples
# Let's consider two other *mysterious* datasets: `mysterious_data_1` and `mysterious_data_2`.

# %%
mysterious_data_1, mysterious_data_2 = utils.load_mysterious_data()

# %%
mysterious_data_1.plot();
plt.xlabel('Time')
plt.title('Mysterious variable 1, monthly');

# %%
mysterious_data_2.plot();
plt.xlabel('Time')
plt.title('Mysterious variable 2, monthly');

# %% [markdown]
# Just from comparing these plots, there is already a visual clue that there is more structure in the first dataset than in the second.
#
# We can continue searching for structure by decomposing the signal. Since the variance does not seem to change in either case, we will consider an `additive` decomposition model.

# %%
decomposition = seasonal_decompose(mysterious_data_1, model='additive')
fig = decomposition.plot()
fig.axes[0].set_title('Mysterious variable 1, monthly')
fig.axes[0].set_ylabel('Original')
fig.axes[3].lines[0].set_markersize(3)
fig.axes[3].set_xlabel('Time');

# %%
decomposition = seasonal_decompose(mysterious_data_2, model='additive')
fig = decomposition.plot()
fig.axes[0].set_title('Mysterious variable 2, monthly')
fig.axes[0].set_ylabel('Original')
fig.axes[3].lines[0].set_markersize(3)
fig.axes[3].set_xlabel('Time');

# %% [markdown]
# Well... `mysterious_data_2` seems much more mysterious than `mysterious_data_1`, but this is all very subjective and possibly misleading. Maybe we have a more objective way to look for structure?

# %% [markdown]
# ## 2. Autocorrelation
#
# In the previous BLU we manually checked the correlation for each lagged version of the timeseries. But I bet you didn't know that we were actually looking at the ACF, which stands for Autocorrelation Function! Here, we're going to learn about ACF, its cousin PACF (**Partial** Autocorrelation Function) and how to calculate them more expeditely.
#
# ### 2.1 ACF
#
# The idea, in plain English, is very simple: _"for a given timeseries, how correlated is each datapoint to the datapoint lagged x periods?"_
#
# #### 2.1.1 Calculating ACF by hand
#
# Original dataset:

# %%
mysterious_data_1.head()
# Out:
# month
# 1971-01-01    454.0
# 1971-02-01    421.0
# 1971-03-01    389.0
# 1971-04-01    368.0
# 1971-05-01    460.0
# Name: consumption, dtype: float64

# %% [markdown]
# The same dataset lagged by 1 period:

# %%
mystery_lag_1 = mysterious_data_1.shift(1)
mystery_lag_1.head()
# Out:
# month
# 1971-01-01      NaN
# 1971-02-01    454.0
# 1971-03-01    421.0
# 1971-04-01    389.0
# 1971-05-01    368.0
# Name: consumption, dtype: float64

# %% [markdown]
# So... the data that was at `1971-01-01` is now at `1971-02-01`, and so on and so forth. Fancy.
#
# How correlated are `mystery_data_1` and `mystery_lag_1`?

# %%
mysterious_data_1.corr(mystery_lag_1)
# Out:
# np.float64(0.5262475690238556)

# %% [markdown]
# Ok... how about if we lag it two times?

# %%
mysterious_data_1.corr(mysterious_data_1.shift(2))
# Out:
# np.float64(-0.14550472700327172)

# %% [markdown]
# Negatively correlated...
#
# Let's get a bunch of these, testing for various lags:

# %%
corrs = {}
for lag in range(40):
    corrs[lag] = mysterious_data_1.corr(mysterious_data_1.shift(lag))

# %%
pd.Series(corrs).head()
# Out:
# 0    1.000000
# 1    0.526248
# 2   -0.145505
# 3   -0.490220
# 4   -0.334527
# dtype: float64

# %%
pd.Series(corrs).plot(kind='bar', figsize=(12,4.2))
plt.xlabel('Lag')
plt.ylabel('Correlation between original and lagged series')
plt.title('Mysterious data 1');

# %% [markdown]
# Wooow! We can see the structure! Every 12 months (year!) we get a really high correlation. And there is an up and down pattern which may be related to the yearly seasons (spring and its friends). Cool bananas.

# %% [markdown]
# #### 2.1.2 ACF with statsmodels
#
# Statsmodels comes with functions to calculate and plot ACF.
#
# But, there's more! It also gives you something super practical: pre-calculated confidence intervals which tell you how significant is the auto-correlation (a.k.a. how statistically reliable are the ACF values).

# %%
# I'm allowed to import stuff in the middle of the notebook, and you aren't. Muahahaha! 
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf

# %%
acf(mysterious_data_1)
# Out:
# array([ 1.        ,  0.52351648, -0.14388441, -0.47602432, -0.32189455,
#         0.02128615,  0.20982187,  0.05729749, -0.29908263, -0.47353522,
#        -0.16368264,  0.44064126,  0.77413446,  0.44222172, -0.14789621,
#        -0.44085934, -0.29582641,  0.00320722,  0.15036108,  0.02568834,
#        -0.27648917])

# %% [markdown]
# Well, that's what we just saw by hand. And the plot?

# %%
plot_acf(mysterious_data_1, alpha=.05)
plt.xlabel('lag')
plt.ylabel('Autocorrelation')
plt.title('Mysterious data 1');

# %% [markdown]
# Preeettyyyyy.... Just by looking at this plot, we can tell that there is some clear seasonal behavior and that it is quite significant around lag 12.
#
# On the other hand, the shaded area is the confidence interval we mentioned before and it illustrates the uncertainty behind the ACF estimates. It always assumes a certain degree of confidence: for example, the parameter `alpha=0.05`, given to `plot_acf` before, is equivalent to assuming a 95% confidence.
#
# To make this even clearer: statsmodels is 95% confident that the ACF value for lag 1 is between the interval 0.523$\pm$0.2 (yes, I rounded the numbers a bit, I'm just that lazy o_o).
#
# But remember! If you're 95% confident, then you're going to be wrong once every 20 times, so take the confidence interval with that pinch of salt.
#
# And if we want to see more lags? Statsmodels got you covered:

# %%
plot_acf(mysterious_data_1, alpha=.05, lags=50)
plt.xlabel('lag')
plt.ylabel('Autocorrelation')
plt.title('Mysterious data 1');

# %% [markdown]
# So, we said this helped find structure. What happens if we apply this to the sneaky looking `mysterious_data_2` that doesn't seem to have any structure?

# %%
plot_acf(mysterious_data_2, alpha=.05, lags=50)
plt.xlabel('lag')
plt.ylabel('Autocorrelation')
plt.title('Mysterious data 2');

# %% [markdown]
# That, ladies and gentlemen, is how you know that noise... is noise :)
#
# The big reveal: `mysterious_data_1` is monthly electricity consumption and `mysterious_data_2` is white noise.

# %% [markdown]
# ### 2.2 PACF
#
# As mentioned in the intro to section 2, [PACF](https://stats.stackexchange.com/questions/129052/acf-and-pacf-formula/129374#129374) stands for Partial Autocorrelation Function.
#
# To illustrate what PACF is used for, I'm going to plot the **old ACF** for `mysterious_data_1`:

# %%
plot_acf(mysterious_data_1, alpha=.05, lags=50)
plt.xlabel('lag')
plt.ylabel('Autocorrelation')
plt.title('Mysterious data 1');

# %% [markdown]
# Again, we can see that lag 12 has a high auto-correlation. But so does lag 24. And lag 36.
#
# Now imagine you walk into the room and share these results with your coworkers:
# > _"I've found something! The pattern seems to happen every year, and every two years, and every 3 years, and every 4 years!"_
#
# You might rightfully be laughed at, right? Because the results, as your phrasing suggested, are kind of "recycling" auto-correlation from the previous year.
#
# Moreover, this remark can be further expanded: any lag can influence its successor (in multiples). Meaning that the lag 1 correlation may be impacting all the other lags (as every integer is a multiple of 1), lag 2 can be impacting lags 4, 6, 8, etc., lag 3 the lags 6, 9, 12, etc., and I think that by now you already get the gist of it.

# %% [markdown]
# Ideally, we'd want to remove the autocorrelation that we've already accounted for, and plot just the "unaccounted for" stuff.
#
# In other words, consider that we have the time series $z$ at time $t$, $z_t$, and we want to find how it correlates with $z$ at time $t - k$, $z_{t - k}$ :
# * ACF will find the correlation including all the terms between $z_t$ and $z_{t - k}$
# * PACF will subtract from the correlation the linear combinations of the terms between $t - 1$ and $t - k - 1$: i.e. the terms from $z_{t - 1}$ to $z_{t - k -1}$. This will result in PACF only accounting for the correlation between $z_t$ and $z_{t - k}$
#
# And that, dear student, is what the PACF is for.

# %%
from statsmodels.tsa.stattools import pacf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(mysterious_data_1, alpha=0.05, lags=50)
plt.xlabel('lag')
plt.ylabel('Autocorrelation')
plt.title('Mysterious data 1');

# %% [markdown]
# If you get a warning from statsmodels and the values of the PACF are outside the [-1,1] bounds, which is **impossible**, it is due to a well known numerical problem that can occur due to the approximations in the calculations. A quick way to solve this warning is to change the underlying method to calculate the PACF:

# %%
plot_pacf(mysterious_data_1, alpha=0.05, lags=50, method='ols')
plt.xlabel('lag')
plt.ylabel('Autocorrelation')
plt.title('Mysterious data 1');

# %% [markdown]
# <img src="media/pacf_cowell2.jpg">
#
# Now it makes sense. The PACF is similar to the ACF but without the repeating correlation lags. So basically, the PACF is showing us the ACF but penalizing seasonality-related autocorrelation. Why do we want this you ask? Well, because we already know that there is seasonality with lag 12.
#
# Thanks to the PACF we are now able to find more possible correlations, which were camouflaged in the ACF by the effect of seasonality. On the PACF we can see much more interesting lags, like lag 2 for example with -0.6 autocorrelation, which was only -0.2 on the ACF. This shows that it was not only the lag 12 correlation which was being "recycled".
#
# In this section we briefly introduced the ACF and PAC, but if you want to take a deeper look at [the maths of it](https://stats.stackexchange.com/questions/129052/acf-and-pacf-formula/129374#129374), feel free!

# %% [markdown]
# ## 3. Stationarity
#
# The concept of autocorrelation is essential for modelling time series, but at least as important is understanding what is the stationarity.
#
# For the math nerds: https://en.wikipedia.org/wiki/Stationary_process#Weak_or_wide-sense_stationarity
#
# For the others, a brief explanation:
#
# > **_"A stationary time series is one whose statistical properties such as mean, variance, autocorrelation, etc. are constant over time."_**
#
# Stationarity is a holy grail in time series, especially if you are using the type of models we will show you next. If a process is stationary, you can learn the patterns in it and predict the same for the future. (Yeah, we can only predict the future if it's the same as the past :) ) Thus, it would totally make sense if we could (and we will!) transform our time series until they are stationary.
#
# First, let's look at a clearly non-stationary time series, our old friend airlines dataset:

# %%
airlines.plot()
plt.xlabel('Time')
plt.title('# Passengers per month (in thousands)');

# %% [markdown]
# **Is the mean constant over time?**
#
# Nop.
#
# **Is the variance constant over time?**
#
# Oh hell no.
#
# **Is the auto-correlation constant over time?**
#
# Hmmm...
#
# Let's beat this timeseries into submission until it becomes stationary!

# %% [markdown]
# ### 3.1 Stabilize Variance
#
# First, we should stabilize the variance so that it is approximately constant over time. The most common way to do that is to apply the log transform, which is just a special case of the [Box-Cox transform](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.boxcox.html). For those interested, it's definitely worth exploring further.
#
# So let's see how log changes our timeseries.

# %%
airlines_logged = airlines.map(np.log)

# %%
fig, ax1 = plt.subplots()
ax1.plot(airlines, ls=':')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_ylabel('Original values, dotted blue', color='tab:blue')
ax2 = ax1.twinx()
ax2.plot(airlines_logged, color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')
ax2.set_ylabel('Logged values, orange', color='tab:orange')
plt.title('# Passengers per month (in thousands)');

# %% [markdown]
# See how the peaks got more evenly sized?
#
# Let's plot the rolling standard deviation again to better see what happened with the variance.

# %%
fig, ax1 = plt.subplots()
ax1.plot(airlines.rolling(12).std(), ls=':')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_ylabel('Original values, dotted blue', color='tab:blue')
ax2 = ax1.twinx()
ax2.plot(airlines_logged.rolling(12).std(), color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')
ax2.set_ylabel('Logged values, orange', color='tab:orange')
plt.title('Rolling stdev: # Passengers per month (in thousands)');

# %% [markdown]
# Notice how the variance in the original timeseries keeps growing, while this trend is greatly mitigated in the logged timeseries!

# %% [markdown]
# ### 3.2 Removing trend
#
# The next step is to remove the trend, so that the mean of the timeseries is approximatelly constant over time. A trivial way to remove the trend is to take the lag 1, and subtract it. In other words, instead of using the series, we will use the difference between consecutive observations.
#
# Difference, you say? difference... Ah! [Diff!](https://pandas.pydata.org/docs/reference/api/pandas.Series.diff.html#pandas.Series.diff)

# %%
airlines_logged_diff = airlines_logged.diff()

# %%
airlines_logged_diff.plot()
plt.xlabel('Time')
plt.title('Diff: # Passengers per month (in thousands)');

# %% [markdown]
# So... mean looks constant over time, variance seems constant over time... looks like we managed!
#
# Note: it's advised to do the log transform first, and then the diff. The reason is that the diff has a tendency to place results at zero, which will prove problematic with the log transform.

# %% [markdown]
# ### 3.3 Other methods
#
# This was clearly an easy-to-make-stationary timeseries. Most cases, in fact, require a lot more work. There are approaches such as removing a moving average that are more powerful, and tend to work quite well.
#
# However, remember this: whatever transformation you do to your timeseries in your attempt to make it stationary, you should be able to reverse it later. If someone asks you
# > _"How many passengers are we going to have next Sunday?"_
#
#
# Answering this won't get you far:
# > _For next Sunday, I predict a logged diff of -0.23."_
#
# So, whenever you are transforming your timeseries, you need to keep these transformations reversible, and the more complex the transformation, the more complex it is to invert.

# %% [markdown]
# ### 3.4 Evaluating stationarity
#
# Is it stationary? It... "looks stationary".
#
# But, as with so many things in life, when you need to quantify them, generally you'll find that there is a way.
#
# <img src="https://i.imgflip.com/2a3kei.jpg" width="300">
#
# For the stationarity, we use the **[Dickey-Fuller test](http://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html#statsmodels.tsa.stattools.adfuller)** (or KPSS or a [bunch](https://www.statsmodels.org/dev/tsa.html#descriptive-statistics-and-tests) of other stationarity tests:

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# The Dickey-Fuller test has the null hypothesis that the [Unit Root](https://en.wikipedia.org/wiki/Unit_root) is present. The details of this are interesting yet out of scope, but suffice it to say for our purposes that if the unit root isn't present, the timeseries can be assumed to be stationary.
#
# So, for the time being, "_Unit Root is bad_ ", and "_no Unit Root is good_ ". Only if the p-value is below a critical size do we have statistical evidence to reject the unit root presence. Thus, there is statistical evidence that our series is stationary.
#
#  So... we want a low p-value. Got that? Great.
#
# So let's just pass it our series...

# %%
try: 
    adfuller(airlines_logged_diff)
except Exception as e:
    print('NEIN! And here is why: %s' % e)
# Out:
# NEIN! And here is why: exog contains inf or nans

# %% [markdown]
# Ah damn it. The reason why we have this try-catch is because you're gonna run into this at some point:
#
# > We forgot to get rid of our missing data. The first point, remember?

# %%
airlines_logged_diff.head(3)
# Out:
# Month
# 1949-01-01         NaN
# 1949-02-01    0.052186
# 1949-03-01    0.112117
# Name: thousands of passengers, dtype: float64

# %% [markdown]
# Trying again without the missing datapoint:

# %%
adfstat, pvalue, usedlag, nobs, critvalues, icbest = adfuller(airlines_logged_diff.dropna())

# %% [markdown]
# Ok, I know, so many returns. It's worth taking a look at [the documentation](http://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html#statsmodels.tsa.stattools.adfuller), but for our purposes, we're going to use it in a ridiculously simple way:

# %%
print('Statistic: %0.02f' % adfstat)
print('pvalue:    %0.03f' % pvalue)
# Out:
# Statistic: -2.72
# pvalue:    0.071

# %% [markdown]
# The p-value is low, but not as low as we normally like it to be (ideally < 0.05). We can't reject that we have unit root at a 95% confidence interval, which is a good rule of thumb. But since this is just an example, this level of confidence is good enough for us.
#
# If we really wanted to have a more stationary time series we could use more sophisticated ways to get rid of the trend (subtracting the rolling mean) or even using `diff` again. But do be careful with the diffs, it's like salt, you want just enough, too much ruins the dish.

# %% [markdown]
# So that's it for the basics of preparing your time series for modelling. In the following notebooks you will find out that some of this work is already done for you in certain libraries, but it's always fundamental that you have an idea of what's going on behind the scenes.
#
# Make sure to check this [article](https://blog.x.com/developer/en_us/topics/tips/2018/evaluating-time-series-and-identifying-trends) from Twitter's `Do More with Twitter Data`, as it describes an excelent example of making time series analysis.
